# %%
import psycopg2 as psyc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %%
conn = psyc.connect(dbname="production", 
                    user="etl", 
                    password="etl1234",
                    host='localhost',
                    port='5403')

# %%
cur = conn.cursor()

# %%
test_query = "SELECT order_created_date_local, COUNT(*) FROM d3.f_order_master GROUP BY order_created_date_local ORDER BY order_created_date_local"

cur.execute(test_query)

# %%
conn.close()

# %%
data = cur.fetchall()
data = np.asarray(data)
data[0]
# Out:
# array([datetime.date(2015, 5, 6), 14L], dtype=object)

# %%
df = pd.DataFrame(data[:, 1], index=data[:, 0], columns=['n_orders'])
df.head()
# Out:
#            n_orders
# 2015-05-06       14
# 2015-05-07        8
# 2015-05-08        3
# 2015-05-09        2
# 2015-05-10        1

# %%
df.plot(figsize=(20, 8))

# %%
df[df.index > datetime.date(2016, 8, 1)].plot(figsize=(20, 5))

# %%
# http://statsmodels.sourceforge.net/0.6.0/generated/statsmodels.tsa.arima_model.ARIMA.html

from statsmodels.tsa.arima_model import ARIMA

# %%
arima = ARIMA()
